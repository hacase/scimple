# %%
import time

string = """Show
Cinemas
In
My
Place
Listing
Everything"""

for char in string:
    print(char, end='')
    time.sleep(.1)
# Out:
# Show
# Cinemas
# In
# My
# Place
# Listing
# Everything

# %%
import sys,time,random

string = """Show
Cinemas
In
My
Place
Listing
Everything"""

typing_speed = 100 #wpm

def slow_type(t):
    for l in t:
        sys.stdout.write(l)
        sys.stdout.flush()
        time.sleep(random.random()*10.0/typing_speed)
    print('')

slow_type(string)
# Out:
# Show
# Cinemas
# In
# My
# Place
# Listing
# Everything

# %%
from urllib.request import urlopen

url = "https://www.bonnerkinemathek.de/programm/"
page = urlopen(url)
html = page.read().decode("utf-8")

title_index = html.find('<div class="title">')
print(title_index)
start_index = title_index + len('<div class="title">')
print(start_index)

title = ''

for i in html[start_index:start_index + 100]:
    if (i == '<'):
        break
    title += i
    
print(title)
# Out:
# 20045
# 20064
# Im Taxi mit Madleleine

# %%
import re
re.findall("a.*c", "ABBCC", re.IGNORECASE)
# Out:
# ['ABBCC']

# %%
from urllib.request import urlopen
import re

url = "https://www.bonnerkinemathek.de/programm/"
page = urlopen(url)
html = page.read().decode("utf-8")

pattern = r'<h2>.*?</a></div>'
match_results = re.findall(pattern, html, re.DOTALL)

for i in match_results:
    print('new', i)
    
    pattern = r'<h2>.*?</h2>'
    date = re.match(pattern, i)
    print('-'*40)
    date = re.sub("<.*?>", "", re.match(pattern, i).group())
    print(date)

print('done')
# Out:
# new <h2>Freitag 02/06/2023</h2><div class="movies-list"><a class="movie block-1" href="https://www.bonnerkinemathek.de/programm/adios-buenos-aires-12/">
#   <img width="318" height="172" src="https://www.bonnerkinemathek.de/content/uploads/2023/05/adiosbuenosaires.jpg" class="attachment-318x195 size-318x195 wp-post-image" alt="Adios, Buenos Aires" loading="lazy" srcset="https://www.bonnerkinemathek.de/content/uploads/2023/05/adiosbuenosaires.jpg 1200w, https://www.bonnerkinemathek.de/content/uploads/2023/05/adiosbuenosaires-300x162.jpg 300w, https://www.bonnerkinemathek.de/content/uploads/2023/05/adiosbuenosaires-1024x553.jpg 1024w, https://www.bonnerkinemathek.de/content/uploads/2023/05/adiosbuenosaires-768x415.jpg 768w, https://www.bonnerkinemathek.de/content/uploads/2023/05/adiosbuenosaires-638x345.jpg 638w, https://www.bonnerkinemathek.de/content/uploads/2023/05/adiosbuenosaires-318x172.jpg 318w" sizes="(max-width: 318px) 100vw, 318px" />
#   <div class="movie-details">
#     <span class="date">18:00</span> <span class="spec">Argentinisches Kino OmU</span>
#     <div class="title">Adios, Buenos Aires</div>
#     <div class="location">Kino in der Brotfabrik</div>
#   </div>
#
# </a><a class="movie block-1" href="https://www.bonnerkinemathek.de/programm/sonne-und-beton/">
#   <img width="138" height="195" src="https://www.bonnerkinemathek.de/content/uploads/2023/05/SuB_final_Motiv2_A4_Berlinale.jpg.jpg" class="attachment-318x195 size-318x195 wp-post-image" alt="Sonne und Beton" loading="lazy" srcset="https://www.bonnerkinemathek.de/content/uploads/2023/05/SuB_final_Motiv2_A4_Berlinale.jpg.jpg 848w, https://www.bonnerkinemathek.de/content/uploads/2023/05/SuB_final_Motiv2_A4_Berlinale.jpg-212x300.jpg 212w, https://www.bonnerkinemathek.de/content/uploads/2023/05/SuB_final_Motiv2_A4_Berlinale.jpg-724x1024.jpg 724w, https://www.bonnerkinemathek.de/content/uploads/2023/05/SuB_final_Motiv2_A4_Berlinale.jpg-768x1087.jpg 768w, https://www.bonnerkinemathek.de/content/uploads/2023/05/SuB_final_Motiv2_A4_Berlinale.jpg-638x903.jpg 638w, https://www.bonnerkinemathek.de/content/uploads/2023/05/SuB_final_Motiv2_A4_Berlinale.jpg-318x450.jpg 318w" sizes="(max-width: 138px) 100vw, 138px" />
#   <div class="movie-details">
#     <span class="date">19:30</span> <span class="spec">Deutsches Kino</span>
#     <div class="title">Sonne und Beton</div>
#     <div class="location">LVR-LandesMuseum Bonn</div>
#   </div>
#
# </a><a class="movie block-1" href="https://www.bonnerkinemathek.de/programm/fucking-bornholm-4/">
#   <img width="293" height="195" src="https://www.bonnerkinemathek.de/content/uploads/2023/05/Fucking-Bornholm.jpg" class="attachment-318x195 size-318x195 wp-post-image" alt="Fucking Bornholm" loading="lazy" srcset="https://www.bonnerkinemathek.de/content/uploads/2023/05/Fucking-Bornholm.jpg 900w, https://www.bonnerkinemathek.de/content/uploads/2023/05/Fucking-Bornholm-300x200.jpg 300w, https://www.bonnerkinemathek.de/content/uploads/2023/05/Fucking-Bornholm-768x512.jpg 768w, https://www.bonnerkinemathek.de/content/uploads/2023/05/Fucking-Bornholm-638x425.jpg 638w, https://www.bonnerkinemathek.de/content/uploads/2023/05/Fucking-Bornholm-318x212.jpg 318w" sizes="(max-width: 293px) 100vw, 293px" />
#   <div class="movie-details">
#     <span class="date">20:00</span> <span class="spec">Polnisches Kino in OmU</span>
#     <div class="title">Fucking Bornholm</div>
#     <div class="location">Kino in der Brotfabrik</div>
#   </div>
#
# </a></div>
# ----------------------------------------
# Freitag 02/06/2023
# new <h2>Samstag 03/06/2023</h2><div class="movies-list"><a class="movie block-1" href="https://www.bonnerkinemathek.de/programm/fucking-bornholm-2/">
#   <img width="293" height="195" src="https://www.bonnerkinemathek.de/content/uploads/2023/05/Fucking-Bornholm.jpg" class="attachment-318x195 size-318x195 wp-post-image" alt="Fucking Bornholm" loading="lazy" srcset="https://www.bonnerkinemathek.de/content/uploads/2023/05/Fucking-Bornholm.jpg 900w, https://www.bonnerkinemathek.de/content/uploads/2023/05/Fucking-Bornholm-300x200.jpg 300w, https://www.bonnerkinemathek.de/content/uploads/2023/05/Fucking-Bornholm-768x512.jpg 768w, https://www.bonnerkinemathek.de/content/uploads/2023/05/Fucking-Bornholm-638x425.jpg 638w, https://www.bonnerkinemathek.de/content/uploads/2023/05/Fucking-Bornholm-318x212.jpg 318w" sizes="(max-width: 293px) 100vw, 293px" />
#   <div class="movie-details">
#     <span class="date">18:30</span> <span class="spec">Polnisches Kino in OmU</span>
#     <div class="title">Fucking Bornholm</div>
#     <div class="location">Kino in der Brotfabrik</div>
#   </div>
#
# </a><a class="movie block-1" href="https://www.bonnerkinemathek.de/programm/adios-buenos-aires-11/">
#   <img width="318" height="172" src="https://www.bonnerkinemathek.de/content/uploads/2023/05/adiosbuenosaires.jpg" class="attachment-318x195 size-318x195 wp-post-image" alt="Adios, Buenos Aires" loading="lazy" srcset="https://www.bonnerkinemathek.de/content/uploads/2023/05/adiosbuenosaires.jpg 1200w, https://www.bonnerkinemathek.de/content/uploads/2023/05/adiosbuenosaires-300x162.jpg 300w, https://www.bonnerkinemathek.de/content/uploads/2023/05/adiosbuenosaires-1024x553.jpg 1024w, https://www.bonnerkinemathek.de/content/uploads/2023/05/adiosbuenosaires-768x415.jpg 768w, https://www.bonnerkinemathek.de/content/uploads/2023/05/adiosbuenosaires-638x345.jpg 638w, https://www.bonnerkinemathek.de/content/uploads/2023/05/adiosbuenosaires-318x172.jpg 318w" sizes="(max-width: 318px) 100vw, 318px" />
#   <div class="movie-details">
#     <span class="date">20:30</span> <span class="spec">Argentinisches Kino OmU</span>
#     <div class="title">Adios, Buenos Aires</div>
#     <div class="location">Kino in der Brotfabrik</div>
#   </div>
#
# </a></div>
# ----------------------------------------
# Samstag 03/06/2023
# new <h2>Sonntag 04/06/2023</h2><div class="movies-list"><a class="movie block-1" href="https://www.bonnerkinemathek.de/programm/heidi-zurueck-in-den-bergen-2/">
#   <img width="261" height="195" src="https://www.bonnerkinemathek.de/content/uploads/2023/05/Heidi-zurueck-in-den-Bergen.jpg" class="attachment-318x195 size-318x195 wp-post-image" alt="Heidi zurück in den Bergen" loading="lazy" srcset="https://www.bonnerkinemathek.de/content/uploads/2023/05/Heidi-zurueck-in-den-Bergen.jpg 1528w, https://www.bonnerkinemathek.de/content/uploads/2023/05/Heidi-zurueck-in-den-Bergen-300x224.jpg 300w, https://www.bonnerkinemathek.de/content/uploads/2023/05/Heidi-zurueck-in-den-Bergen-1024x766.jpg 1024w, https://www.bonnerkinemathek.de/content/uploads/2023/05/Heidi-zurueck-in-den-Bergen-768x574.jpg 768w, https://www.bonnerkinemathek.de/content/uploads/2023/05/Heidi-zurueck-in-den-Bergen-638x477.jpg 638w, https://www.bonnerkinemathek.de/content/uploads/2023/05/Heidi-zurueck-in-den-Bergen-318x238.jpg 318w" sizes="(max-width: 261px) 100vw, 261px" />
#   <div class="movie-details">
#     <span class="date">14:00</span> <span class="spec"></span>
#     <div class="title">Heidi zurück in den Bergen</div>
#     <div class="location">Kino in der Brotfabrik</div>
#   </div>
#   	<ul class="event-categories-images">
# 								<li><img src='https://www.bonnerkinemathek.de/content/uploads/2013/02/kinokids.png' alt='Kino für Kids'/></li>
# 								</ul>
#
# </a><a class="movie block-1" href="https://www.bonnerkinemathek.de/programm/der-vermessene-mensch-10/">
# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

url = "https://www.bonnerkinemathek.de/programm/"
page = urlopen(url)
html = page.read().decode("utf-8")
soup = BeautifulSoup(html, "html.parser")

for a in soup.findAll('h2', href=True, attrs={''})

#print(soup.get_text())
# Out:
#   File "<ipython-input-108-1f1ee03e3e5b>", line 9
#     for a in soup.findAll('h2', href=True, attrs={''})
#                                                       ^
# SyntaxError: invalid syntax

# %%
from urllib.request import urlopen
import re
from bs4 import BeautifulSoup

url = "https://www.bonnerkinemathek.de/programm/"
page = urlopen(url)
html = page.read().decode("utf-8")

pattern = r'<h2>.*?</a></div>'
match_results = re.findall(pattern, html, re.DOTALL)

for i in match_results:    
    soup = BeautifulSoup(i, "html.parser")
    
    date = re.sub("<.*?>", "", str(soup.find("h2")))
    print(date)
    
    print(soup.find_all("div", class_="title"))
    
    title = soup.find_all("div", attrs={'class':'title'})
    print(type(title))
    
    title = soup.find_all("div", class_="title")
    print(type(title))
    
    title = re.sub("<.*?>", "", title.text)
    spec = re.sub("<.*?>", "", str(soup.find_all("span", class_="spec")))
    time = re.sub("<.*?>", "", str(soup.find_all("span", class_="date")))
    location = re.sub("<.*?>", "", str(soup.find_all("div", class_="location")))
    
    for i in range(len(title)):
        print(title[i])
        print(spec[i])
        print(time[i])
        print(location[i])
    print(title)

print('done')
# Out:
# Freitag 02/06/2023
# [<div class="title">Adios, Buenos Aires</div>, <div class="title">Sonne und Beton</div>, <div class="title">Fucking Bornholm</div>]
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.ResultSet'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-187-751ce6245295> in <module>
#      24     print(type(title))
#      25
# ---> 26     title = re.sub("<.*?>", "", title.text)
#      27     spec = re.sub("<.*?>", "", str(soup.find_all("span", class_="spec")))
#      28     time = re.sub("<.*?>", "", str(soup.find_all("span", class_="date")))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bs4/element.py in __getattr__(self, key)
#    2171     def __getattr__(self, key):
#    2172         """Raise a helpful exception to explain a common code fix."""
# -> 2173         raise AttributeError(
#    2174             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2175         )
#
# AttributeError: ResultSet object has no attribute 'text'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
from urllib.request import urlopen
import re
from bs4 import BeautifulSoup

date = []
title = []
spec = []
time = []
location = []
ticket = []

url = "https://www.bonnerkinemathek.de/programm/"
page = urlopen(url)
html = page.read().decode("utf-8")

pattern = r'<h2>.*?</a></div>'
match_results = re.findall(pattern, html, re.DOTALL)

for i in match_results:    
    soup = BeautifulSoup(i, "html.parser")
    
    for i in range(100):
        try:
            date.append(re.sub("<.*?>", "", str(soup.find("h2"))))
            title.append(re.sub("<.*?>", "", soup.find_all("div", class_="title")[i].text))
            spec.append(re.sub("<.*?>", "", soup.find_all("span", class_="spec")[i].text))
            time.append(re.sub("<.*?>", "", soup.find_all("span", class_="date")[i].text))
            location.append(re.sub("<.*?>", "", soup.find_all("div", class_="location")[i].text))
            ticket.append(re.sub("<.*?>", "", soup.find_all("a", class_="movie block-1", href=True)[i].text))
        except:
            break
            
print(date[i])
for i in range(len(title)):
    if (date[i] != date[i+1]) or (i+1 == len(date)):
        print(date[i])

    print(title[i])
    print(ticket[i])
    print(spec[i], time[i])
    print(location[i], "\n")


print('done')
# Out:
# Sonntag 04/06/2023
# Sonntag 04/06/2023
# Heidi zurück in den Bergen
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-217-dd72d218bf82> in <module>
#      37
#      38     print(title[i])
# ---> 39     print(ticket[i])
#      40     print(spec[i], time[i])
#      41     print(location[i], "\n")
#
# IndexError: list index out of range

# %%
from urllib.request import urlopen
import re
from bs4 import BeautifulSoup

date = []
title = []
spec = []
time = []
location = []
ticket = []

url = "https://www.bonnerkinemathek.de/programm/"
page = urlopen(url)
html = page.read().decode("utf-8")

pattern = r'<h2>.*?</a></div>'
match_results = re.findall(pattern, html, re.DOTALL)

for i in match_results:    
    soup = BeautifulSoup(i, "html.parser")
    
    for i in range(100):
        try:
            title.append(re.sub("<.*?>", "", soup.find_all("div", class_="title")[i].text))
            date.append(re.sub("<.*?>", "", str(soup.find("h2"))))
            spec.append(re.sub("<.*?>", "", soup.find_all("span", class_="spec")[i].text))
            time.append(re.sub("<.*?>", "", soup.find_all("span", class_="date")[i].text))
            location.append(re.sub("<.*?>", "", soup.find_all("div", class_="location")[i].text))
            ticket.append(re.sub("<.*?>", "", soup.find_all("a", class_="movie block-1", href=True)[i]['href']))
        except:
            break
            
for i in range(len(title)):
    if (date[i] != date[i-1]) or (i+1 == len(date)):
        print('-'*40)
        print(date[i])
        print('-'*40)

    print(title[i])
    print(ticket[i])
    print(spec[i], time[i])
    print(location[i], "\n")


print('done')
# Out:
# ----------------------------------------
# Sonntag 04/06/2023
# ----------------------------------------
# Heidi zurück in den Bergen
# https://www.bonnerkinemathek.de/programm/heidi-zurueck-in-den-bergen-2/
#  14:00
# Kino in der Brotfabrik
#
# Der vermessene Mensch
# https://www.bonnerkinemathek.de/programm/der-vermessene-mensch-10/
# Deutsches Kino 16:00
# Kino in der Brotfabrik
#
# The Whale
# https://www.bonnerkinemathek.de/programm/the-whale-5/
# US-Amerikanisches Kino in OmU 18:30
# Kino in der Brotfabrik
#
# ----------------------------------------
# Montag 05/06/2023
# ----------------------------------------
# Adios, Buenos Aires
# https://www.bonnerkinemathek.de/programm/adios-buenos-aires-13/
# Argentinisches Kino OmU 18:00
# Kino in der Brotfabrik
#
# Fucking Bornholm
# https://www.bonnerkinemathek.de/programm/fucking-bornholm-5/
# Polnisches Kino in OmU 20:00
# Kino in der Brotfabrik
#
# ----------------------------------------
# Dienstag 06/06/2023
# ----------------------------------------
# Fucking Bornholm
# https://www.bonnerkinemathek.de/programm/fucking-bornholm-6/
# Polnisches Kino in OmU 18:00
# Kino in der Brotfabrik
#
# The Whale
# https://www.bonnerkinemathek.de/programm/the-whale-6/
# US-Amerikanisches Kino in OmU 19:30
# LVR-LandesMuseum Bonn
#
# Sonne und Beton
# https://www.bonnerkinemathek.de/programm/sonne-und-beton-2/
# Deutsches Kino 20:00
# Kino in der Brotfabrik
#
# ----------------------------------------
# Mittwoch 07/06/2023
# ----------------------------------------
# Fellinis Stadt der Frauen
# https://www.bonnerkinemathek.de/programm/fellinis-stadt-der-frauen-2/
# Italienische Filmreihe: Paradoxe Emanzipationen, Mit Einführung, OmU 18:00
# Kino in der Brotfabrik
#
# Sonne und Beton
# https://www.bonnerkinemathek.de/programm/sonne-und-beton-3/
# Deutsches Kino 21:00
# Kino in der Brotfabrik
#
# ----------------------------------------
# Montag 26/06/2023
# ----------------------------------------
# Everything Everywhere All At Once
# https://www.bonnerkinemathek.de/programm/everything-everywhere-all-at-once-11/
#  19:30
# Kino in der Brotfabrik
#
# done
